# %%
#dependencias
import sys
import geopandas as gpd
import sympy
import numpy as np

# %%
print("--- Verificación del Entorno ---")
print(f"Ruta de Python activa: {sys.executable}")
print(f"Versión de GeoPandas: {gpd.__version__}")
print(f"Versión de SymPy: {sympy.__version__}")
print("\nTodo correcto!")
# Out:
# --- Verificación del Entorno ---
# Ruta de Python activa: /home/ubuntu/projects/analisis_espacial_marginalNoise/.venv/bin/python
# Versión de GeoPandas: 1.1.2
# Versión de SymPy: 1.14.0
#
# Todo correcto!
